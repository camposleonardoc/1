# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import KFold
from sklearn import linear_model
from sklearn.metrics import r2_score
from sklearn.model_selection import LeaveOneOut
from sklearn import linear_model
from sklearn.model_selection import train_test_split

# %%
data = pd.read_csv('base_datos_2008.csv')

df = data.dropna(subset = ['ArrDelay'])

df = df.sample(frac=1).head(5000)

df = df.reset_index()

X = df[['AirTime','Distance','DepDelay']]

Y = df['ArrDelay']

# %%
X_train, X_test, Y_train, Y_test= train_test_split(X, Y, test_size=.2, random_state=1)

#Cross Validator
loo = LeaveOneOut()

# %%
for train_index, test_index in loo.split(X):
    X_train, X_test = X.loc[train_index,], X.loc[test_index]
    Y_train, Y_test = Y[train_index], Y[test_index]
    regr.fit(X_train,Y_train)
    predicciones = regr.predict(X_test)
    print('Error: ',(Y_test - predicciones[0])**2)
# Out:
# Error:  0    464.959056
# Name: ArrDelay, dtype: float64
# Error:  1    40.227286
# Name: ArrDelay, dtype: float64
# Error:  2    899.504582
# Name: ArrDelay, dtype: float64
# Error:  3    30.344824
# Name: ArrDelay, dtype: float64
# Error:  4    67.638513
# Name: ArrDelay, dtype: float64
# Error:  5    90.427405
# Name: ArrDelay, dtype: float64
# Error:  6    33.134048
# Name: ArrDelay, dtype: float64
# Error:  7    9.610758
# Name: ArrDelay, dtype: float64
# Error:  8    30.818061
# Name: ArrDelay, dtype: float64
# Error:  9    0.016606
# Name: ArrDelay, dtype: float64
# Error:  10    0.006583
# Name: ArrDelay, dtype: float64
# Error:  11    108.73879
# Name: ArrDelay, dtype: float64
# Error:  12    13.037373
# Name: ArrDelay, dtype: float64
# Error:  13    46.180691
# Name: ArrDelay, dtype: float64
# Error:  14    126.038473
# Name: ArrDelay, dtype: float64
# Error:  15    24.747826
# Name: ArrDelay, dtype: float64
# Error:  16    9551.444089
# Name: ArrDelay, dtype: float64
# Error:  17    51.180083
# Name: ArrDelay, dtype: float64
# Error:  18    434.126951
# Name: ArrDelay, dtype: float64
# Error:  19    29.372403
# Name: ArrDelay, dtype: float64
# Error:  20    88.961068
# Name: ArrDelay, dtype: float64
# Error:  21    7.933597
# Name: ArrDelay, dtype: float64
# Error:  22    218.526691
# Name: ArrDelay, dtype: float64
# Error:  23    77.139481
# Name: ArrDelay, dtype: float64
# Error:  24    0.22865
# Name: ArrDelay, dtype: float64
# Error:  25    0.238437
# Name: ArrDelay, dtype: float64
# Error:  26    52.708606
# Name: ArrDelay, dtype: float64
# Error:  27    254.800009
# Name: ArrDelay, dtype: float64
# Error:  28    49.57739
# Name: ArrDelay, dtype: float64
# Error:  29    660.709292
# Name: ArrDelay, dtype: float64
# Error:  30    18.725554
# Name: ArrDelay, dtype: float64
# Error:  31    25.171028
# Name: ArrDelay, dtype: float64
# Error:  32    361.197725
# Name: ArrDelay, dtype: float64
# Error:  33    74.13072
# Name: ArrDelay, dtype: float64
# Error:  34    7.021031
# Name: ArrDelay, dtype: float64
# Error:  35    478.313625
# Name: ArrDelay, dtype: float64
# Error:  36    2.104777
# Name: ArrDelay, dtype: float64
# Error:  37    75.340427
# Name: ArrDelay, dtype: float64
# Error:  38    13.253817
# Name: ArrDelay, dtype: float64
# Error:  39    6.805698
# Name: ArrDelay, dtype: float64
# Error:  40    306.282129
# Name: ArrDelay, dtype: float64
# Error:  41    198.379201
# Name: ArrDelay, dtype: float64
# Error:  42    5.652113
# Name: ArrDelay, dtype: float64
# Error:  43    1.927245
# Name: ArrDelay, dtype: float64
# Error:  44    287.00912
# Name: ArrDelay, dtype: float64
# Error:  45    387.412797
# Name: ArrDelay, dtype: float64
# Error:  46    2.124503
# Name: ArrDelay, dtype: float64
# Error:  47    41.788373
# Name: ArrDelay, dtype: float64
# Error:  48    201.900214
# Name: ArrDelay, dtype: float64
# Error:  49    70.31927
# Name: ArrDelay, dtype: float64
# Error:  50    1425.622768
# Name: ArrDelay, dtype: float64
# Error:  51    22.983585
# Name: ArrDelay, dtype: float64
# Error:  52    21.827228
# Name: ArrDelay, dtype: float64
# Error:  53    286.348803
# Name: ArrDelay, dtype: float64
# Error:  54    6.44541
# Name: ArrDelay, dtype: float64
# Error:  55    2.898918
# Name: ArrDelay, dtype: float64
# Error:  56    35.101711
# Name: ArrDelay, dtype: float64
# Error:  57    19.056252
# Name: ArrDelay, dtype: float64
# Error:  58    151.368611
# Name: ArrDelay, dtype: float64
# Error:  59    52.740873
# Name: ArrDelay, dtype: float64
# Error:  60    12.800959
# Name: ArrDelay, dtype: float64
# Error:  61    10.433964
# Name: ArrDelay, dtype: float64
# Error:  62    27.257559
# Name: ArrDelay, dtype: float64
# Error:  63    55.387348
# Name: ArrDelay, dtype: float64
# Error:  64    22.36556
# Name: ArrDelay, dtype: float64
# Error:  65    2.162796
# Name: ArrDelay, dtype: float64
# Error:  66    21.513975
# Name: ArrDelay, dtype: float64
# Error:  67    11.808842
# Name: ArrDelay, dtype: float64
# Error:  68    6.307332
# Name: ArrDelay, dtype: float64
# Error:  69    34.572973
# Name: ArrDelay, dtype: float64
# Error:  70    73.096556
# Name: ArrDelay, dtype: float64
# Error:  71    514.843683
# Name: ArrDelay, dtype: float64
# Error:  72    20.541202
# Name: ArrDelay, dtype: float64
# Error:  73    2.715203
# Name: ArrDelay, dtype: float64
# Error:  74    137.35539
# Name: ArrDelay, dtype: float64
# Error:  75    29.930475
# Name: ArrDelay, dtype: float64
# Error:  76    350.499616
# Name: ArrDelay, dtype: float64
# Error:  77    27.464275
# Name: ArrDelay, dtype: float64
# Error:  78    297.38674
# Name: ArrDelay, dtype: float64
# Error:  79    0.076124
# Name: ArrDelay, dtype: float64
# Error:  80    200.190129
# Name: ArrDelay, dtype: float64
# Error:  81    4.220253
# Name: ArrDelay, dtype: float64
# Error:  82    206.913793
# Name: ArrDelay, dtype: float64
# Error:  83    17.294738
# Name: ArrDelay, dtype: float64
# Error:  84    70.752709
# Name: ArrDelay, dtype: float64
# Error:  85    96.464754
# Name: ArrDelay, dtype: float64
# Error:  86    309.284249
# Name: ArrDelay, dtype: float64
# Error:  87    3.098433
# Name: ArrDelay, dtype: float64
# Error:  88    59.74259
# Name: ArrDelay, dtype: float64
# Error:  89    33.209963
# Name: ArrDelay, dtype: float64
# Error:  90    13.348036
# Name: ArrDelay, dtype: float64
# Error:  91    577.957169
# Name: ArrDelay, dtype: float64
# Error:  92    623.408477
# Name: ArrDelay, dtype: float64
# Error:  93    41.766655
# Name: ArrDelay, dtype: float64
# Error:  94    45.902447
# Name: ArrDelay, dtype: float64
# Error:  95    0.098181
# Name: ArrDelay, dtype: float64
# Error:  96    0.020809
# Name: ArrDelay, dtype: float64
# Error:  97    44.169535
# Name: ArrDelay, dtype: float64
# Error:  98    1746.311363
# Name: ArrDelay, dtype: float64
# Error:  99    5.179964
# Name: ArrDelay, dtype: float64
# Error:  100    0.660694
# Name: ArrDelay, dtype: float64
# Error:  101    29.112555
# Name: ArrDelay, dtype: float64
# Error:  102    310.698896
# Name: ArrDelay, dtype: float64
# Error:  103    64.151176
# Name: ArrDelay, dtype: float64
# Error:  104    414.324572
# Name: ArrDelay, dtype: float64
# Error:  105    351.012224
# Name: ArrDelay, dtype: float64
# Error:  106    71.949242
# Name: ArrDelay, dtype: float64
# Error:  107    125.125395
# Name: ArrDelay, dtype: float64
# Error:  108    80.563661
# Name: ArrDelay, dtype: float64
# Error:  109    47.484853
# Name: ArrDelay, dtype: float64
# Error:  110    22.536709
# Name: ArrDelay, dtype: float64
# Error:  111    59.313129
# Name: ArrDelay, dtype: float64
# Error:  112    58.178835
# Name: ArrDelay, dtype: float64
# Error:  113    175.830889
# Name: ArrDelay, dtype: float64
# Error:  114    79.886991
# Name: ArrDelay, dtype: float64
# Error:  115    24.88946
# Name: ArrDelay, dtype: float64
# Error:  116    406.885615
# Name: ArrDelay, dtype: float64
# Error:  117    8.841514
# Name: ArrDelay, dtype: float64
# Error:  118    14.598748
# Name: ArrDelay, dtype: float64
# Error:  119    1.494931
# Name: ArrDelay, dtype: float64
# Error:  120    12.202188
# Name: ArrDelay, dtype: float64
# Error:  121    89.95992
# Name: ArrDelay, dtype: float64
# Error:  122    0.192122
# Name: ArrDelay, dtype: float64
# Error:  123    201.366812
# Name: ArrDelay, dtype: float64
# Error:  124    143.223551
# Name: ArrDelay, dtype: float64
# Error:  125    47.168546
# Name: ArrDelay, dtype: float64
# Error:  126    188.89975
# Name: ArrDelay, dtype: float64
# Error:  127    312.74199
# Name: ArrDelay, dtype: float64
# Error:  128    167.543259
# Name: ArrDelay, dtype: float64
# Error:  129    2.678802
# Name: ArrDelay, dtype: float64
# Error:  130    28.426113
# Name: ArrDelay, dtype: float64
# Error:  131    66.507173
# Name: ArrDelay, dtype: float64
# Error:  132    64.622452
# Name: ArrDelay, dtype: float64
# Error:  133    5.47362
# Name: ArrDelay, dtype: float64
# Error:  134    1.933591
# Name: ArrDelay, dtype: float64
# Error:  135    22.758458
# Name: ArrDelay, dtype: float64
# Error:  136    4.382316
# Name: ArrDelay, dtype: float64
# Error:  137    82.959772
# Name: ArrDelay, dtype: float64
# Error:  138    33.984927
# Name: ArrDelay, dtype: float64
# Error:  139    2.728355
# Name: ArrDelay, dtype: float64
# Error:  140    11.452363
# Name: ArrDelay, dtype: float64
# Error:  141    56.888526
# Name: ArrDelay, dtype: float64
# Error:  142    172.654505
# Name: ArrDelay, dtype: float64
# Error:  143    0.090132
# Name: ArrDelay, dtype: float64
# Error:  144    33.8159
# Name: ArrDelay, dtype: float64
# Error:  145    16.672517
# Name: ArrDelay, dtype: float64
# Error:  146    352.012997
# Name: ArrDelay, dtype: float64
# Error:  147    4.091268
# Name: ArrDelay, dtype: float64
# Error:  148    39.439847
# Name: ArrDelay, dtype: float64
# Error:  149    37.401615
# Name: ArrDelay, dtype: float64
# Error:  150    86.218927
# Name: ArrDelay, dtype: float64
# Error:  151    614.604518
# Name: ArrDelay, dtype: float64
# Error:  152    117.994602
# Name: ArrDelay, dtype: float64
# Error:  153    33.844318
# Name: ArrDelay, dtype: float64
# Error:  154    0.073078
# Name: ArrDelay, dtype: float64
# Error:  155    25.921116
# Name: ArrDelay, dtype: float64
# Error:  156    34.420938
# Name: ArrDelay, dtype: float64
# Error:  157    7.926765
# Name: ArrDelay, dtype: float64
# Error:  158    34.361483
# Name: ArrDelay, dtype: float64
# Error:  159    1.746553
# Name: ArrDelay, dtype: float64
# Error:  160    28.947481
# Name: ArrDelay, dtype: float64
# Error:  161    64.700075
# Name: ArrDelay, dtype: float64
# Error:  162    121.209584
# Name: ArrDelay, dtype: float64
# Error:  163    43.251706
# Name: ArrDelay, dtype: float64
# Error:  164    46.363746
# Name: ArrDelay, dtype: float64
# Error:  165    0.020894
# Name: ArrDelay, dtype: float64
# Error:  166    353.441981
# Name: ArrDelay, dtype: float64
# Error:  167    0.039278
# Name: ArrDelay, dtype: float64
# Error:  168    146.497164
# Name: ArrDelay, dtype: float64
# Error:  169    1.665756
# Name: ArrDelay, dtype: float64
# Error:  170    183.483142
# Name: ArrDelay, dtype: float64
# Error:  171    0.359009
# Name: ArrDelay, dtype: float64
# Error:  172    93.171008
# Name: ArrDelay, dtype: float64
# Error:  173    13.613562
# Name: ArrDelay, dtype: float64
# Error:  174    27.651693
# Name: ArrDelay, dtype: float64
# Error:  175    31.740486
# Name: ArrDelay, dtype: float64
# Error:  176    21.879894
# Name: ArrDelay, dtype: float64
# Error:  177    42.210338
# Name: ArrDelay, dtype: float64
# Error:  178    0.459426
# Name: ArrDelay, dtype: float64
# Error:  179    12.053046
# Name: ArrDelay, dtype: float64
# Error:  180    259.239483
# Name: ArrDelay, dtype: float64
# Error:  181    25.7212
# Name: ArrDelay, dtype: float64
# Error:  182    1.31547
# Name: ArrDelay, dtype: float64
# Error:  183    47.998559
# Name: ArrDelay, dtype: float64
# Error:  184    24.576802
# Name: ArrDelay, dtype: float64
# Error:  185    91.200234
# Name: ArrDelay, dtype: float64
# Error:  186    67.799708
# Name: ArrDelay, dtype: float64
# Error:  187    17.42391
# Name: ArrDelay, dtype: float64
# Error:  188    21.706068
# Name: ArrDelay, dtype: float64
# Error:  189    179.798536
# Name: ArrDelay, dtype: float64
# Error:  190    1.238602
# Name: ArrDelay, dtype: float64
# Error:  191    2.793492
# Name: ArrDelay, dtype: float64
# Error:  192    43.33582
# Name: ArrDelay, dtype: float64
# Error:  193    335.260513
# Name: ArrDelay, dtype: float64
# Error:  194    57.070094
# Name: ArrDelay, dtype: float64
# Error:  195    10.159976
# Name: ArrDelay, dtype: float64
# Error:  196    17.624591
# Name: ArrDelay, dtype: float64
# Error:  197    235.50447
# Name: ArrDelay, dtype: float64
# Error:  198    10.956189
# Name: ArrDelay, dtype: float64
# Error:  199    36.803946
# Name: ArrDelay, dtype: float64
# Error:  200    177.909991
# Name: ArrDelay, dtype: float64
# Error:  201    131.835384
# Name: ArrDelay, dtype: float64
# Error:  202    30.458037
# Name: ArrDelay, dtype: float64
# Error:  203    0.467133
# Name: ArrDelay, dtype: float64
# Error:  204    168.63866
# Name: ArrDelay, dtype: float64
# Error:  205    33.443465
# Name: ArrDelay, dtype: float64
# Error:  206    0.004687
# Name: ArrDelay, dtype: float64
# Error:  207    13.545774
# Name: ArrDelay, dtype: float64
# Error:  208    24.1487
# Name: ArrDelay, dtype: float64
# Error:  209    108.300136
# Name: ArrDelay, dtype: float64
# Error:  210    197.784321
# Name: ArrDelay, dtype: float64
# Error:  211    207.020686
# Name: ArrDelay, dtype: float64
# Error:  212    5.105061
# Name: ArrDelay, dtype: float64
# Error:  213    5.412801
# Name: ArrDelay, dtype: float64
# Error:  214    328.082705
# Name: ArrDelay, dtype: float64
# Error:  215    67.74181
# Name: ArrDelay, dtype: float64
# Error:  216    214.388961
# Name: ArrDelay, dtype: float64
# Error:  217    190.72045
# Name: ArrDelay, dtype: float64
# Error:  218    249.779635
# Name: ArrDelay, dtype: float64
# Error:  219    168.372583
# Name: ArrDelay, dtype: float64
# Error:  220    144.659182
# Name: ArrDelay, dtype: float64
# Error:  221    33.014982
# Name: ArrDelay, dtype: float64
# Error:  222    0.005311
# Name: ArrDelay, dtype: float64
# Error:  223    109.078132
# Name: ArrDelay, dtype: float64
# Error:  224    0.272775
# Name: ArrDelay, dtype: float64
# Error:  225    11.651312
# Name: ArrDelay, dtype: float64
# Error:  226    128.415809
# Name: ArrDelay, dtype: float64
# Error:  227    777.821298
# Name: ArrDelay, dtype: float64
# Error:  228    347.151066
# Name: ArrDelay, dtype: float64
# Error:  229    36.521945
# Name: ArrDelay, dtype: float64
# Error:  230    110.3809
# Name: ArrDelay, dtype: float64
# Error:  231    5.910425
# Name: ArrDelay, dtype: float64
# Error:  232    355.794662
# Name: ArrDelay, dtype: float64
# Error:  233    24.95524
# Name: ArrDelay, dtype: float64
# Error:  234    70.367862
# Name: ArrDelay, dtype: float64
# Error:  235    314.679367
# Name: ArrDelay, dtype: float64
# Error:  236    62.320141
# Name: ArrDelay, dtype: float64
# Error:  237    29.141321
# Name: ArrDelay, dtype: float64
# Error:  238    7.13172
# Name: ArrDelay, dtype: float64
# Error:  239    114.771629
# Name: ArrDelay, dtype: float64
# Error:  240    16.151226
# Name: ArrDelay, dtype: float64
# Error:  241    15.344028
# Name: ArrDelay, dtype: float64
# Error:  242    0.477488
# Name: ArrDelay, dtype: float64
# Error:  243    1.320364
# Name: ArrDelay, dtype: float64
# Error:  244    43.642536
# Name: ArrDelay, dtype: float64
# Error:  245    28.12224
# Name: ArrDelay, dtype: float64
# Error:  246    2.345697
# Name: ArrDelay, dtype: float64
# Error:  247    27.856308
# Name: ArrDelay, dtype: float64
# Error:  248    300.396089
# Name: ArrDelay, dtype: float64
# Error:  249    229.872513
# Name: ArrDelay, dtype: float64
# Error:  250    428.535888
# Name: ArrDelay, dtype: float64
# Error:  251    31.603496
# Name: ArrDelay, dtype: float64
# Error:  252    0.102949
# Name: ArrDelay, dtype: float64
# Error:  253    349.358604
# Name: ArrDelay, dtype: float64
# Error:  254    46.561806
# Name: ArrDelay, dtype: float64
# Error:  255    1115.32842
# Name: ArrDelay, dtype: float64
# Error:  256    821.092054
# Name: ArrDelay, dtype: float64
# Error:  257    0.39874
# Name: ArrDelay, dtype: float64
# Error:  258    87.619345
# Name: ArrDelay, dtype: float64
# Error:  259    148.831753
# Name: ArrDelay, dtype: float64
# Error:  260    97.356894
# Name: ArrDelay, dtype: float64
# Error:  261    239.953451
# Name: ArrDelay, dtype: float64
# Error:  262    1408.109095
# Name: ArrDelay, dtype: float64
# Error:  263    92.755938
# Name: ArrDelay, dtype: float64
# Error:  264    29.954406
# Name: ArrDelay, dtype: float64
# Error:  265    7.744483
# Name: ArrDelay, dtype: float64
# Error:  266    4.250412
# Name: ArrDelay, dtype: float64
# Error:  267    81.388587
# Name: ArrDelay, dtype: float64
# Error:  268    2.572416
# Name: ArrDelay, dtype: float64
# Error:  269    376.591932
# Name: ArrDelay, dtype: float64
# Error:  270    230.160241
# Name: ArrDelay, dtype: float64
# Error:  271    207.447304
# Name: ArrDelay, dtype: float64
# Error:  272    36.886395
# Name: ArrDelay, dtype: float64
# Error:  273    118.684948
# Name: ArrDelay, dtype: float64
# Error:  274    14.6692
# Name: ArrDelay, dtype: float64
# Error:  275    573.98377
# Name: ArrDelay, dtype: float64
# Error:  276    70.088496
# Name: ArrDelay, dtype: float64
# Error:  277    6.701036
# Name: ArrDelay, dtype: float64
# Error:  278    77.038801
# Name: ArrDelay, dtype: float64
# Error:  279    212.299846
# Name: ArrDelay, dtype: float64
# Error:  280    8.48993
# Name: ArrDelay, dtype: float64
# Error:  281    246.84086
# Name: ArrDelay, dtype: float64
# Error:  282    53.350481
# Name: ArrDelay, dtype: float64
# Error:  283    1.651982
# Name: ArrDelay, dtype: float64
# Error:  284    154.393879
# Name: ArrDelay, dtype: float64
# Error:  285    59.009479
# Name: ArrDelay, dtype: float64
# Error:  286    1149.877193
# Name: ArrDelay, dtype: float64
# Error:  287    172.883119
# Name: ArrDelay, dtype: float64
# Error:  288    2.268816
# Name: ArrDelay, dtype: float64
# Error:  289    0.122977
# Name: ArrDelay, dtype: float64
# Error:  290    4.648007
# Name: ArrDelay, dtype: float64
# Error:  291    24.497429
# Name: ArrDelay, dtype: float64
# Error:  292    57.898059
# Name: ArrDelay, dtype: float64
# Error:  293    213.966552
# Name: ArrDelay, dtype: float64
# Error:  294    16.1584
# Name: ArrDelay, dtype: float64
# Error:  295    0.090182
# Name: ArrDelay, dtype: float64
# Error:  296    25.254439
# Name: ArrDelay, dtype: float64
# Error:  297    1.247261
# Name: ArrDelay, dtype: float64
# Error:  298    169.93378
# Name: ArrDelay, dtype: float64
# Error:  299    2.258693
# Name: ArrDelay, dtype: float64
# Error:  300    842.052756
# Name: ArrDelay, dtype: float64
# Error:  301    1453.602428
# Name: ArrDelay, dtype: float64
# Error:  302    16.023645
# Name: ArrDelay, dtype: float64
# Error:  303    0.689264
# Name: ArrDelay, dtype: float64
# Error:  304    0.263095
# Name: ArrDelay, dtype: float64
# Error:  305    23.997265
# Name: ArrDelay, dtype: float64
# Error:  306    17.661804
# Name: ArrDelay, dtype: float64
# Error:  307    19.642598
# Name: ArrDelay, dtype: float64
# Error:  308    69.423879
# Name: ArrDelay, dtype: float64
# Error:  309    56.163443
# Name: ArrDelay, dtype: float64
# Error:  310    125.488405
# Name: ArrDelay, dtype: float64
# Error:  311    377.373669
# Name: ArrDelay, dtype: float64
# Error:  312    1195.019909
# Name: ArrDelay, dtype: float64
# Error:  313    1000.090787
# Name: ArrDelay, dtype: float64
# Error:  314    10.198614
# Name: ArrDelay, dtype: float64
# Error:  315    129.466356
# Name: ArrDelay, dtype: float64
# Error:  316    132.828591
# Name: ArrDelay, dtype: float64
# Error:  317    1309.301788
# Name: ArrDelay, dtype: float64
# Error:  318    797.549181
# Name: ArrDelay, dtype: float64
# Error:  319    1.27729
# Name: ArrDelay, dtype: float64
# Error:  320    0.404108
# Name: ArrDelay, dtype: float64
# Error:  321    45.919987
# Name: ArrDelay, dtype: float64
# Error:  322    28.8092
# Name: ArrDelay, dtype: float64
# Error:  323    755.389694
# Name: ArrDelay, dtype: float64
# Error:  324    222.185667
# Name: ArrDelay, dtype: float64
# Error:  325    15.269565
# Name: ArrDelay, dtype: float64
# Error:  326    0.118303
# Name: ArrDelay, dtype: float64
# Error:  327    5237.773313
# Name: ArrDelay, dtype: float64
# Error:  328    87.909136
# Name: ArrDelay, dtype: float64
# Error:  329    202.311275
# Name: ArrDelay, dtype: float64
# Error:  330    246.037089
# Name: ArrDelay, dtype: float64
# Error:  331    20.236465
# Name: ArrDelay, dtype: float64
# Error:  332    110.113133
# Name: ArrDelay, dtype: float64
# Error:  333    526.002742
# Name: ArrDelay, dtype: float64
# Error:  334    282.460613
# Name: ArrDelay, dtype: float64
# Error:  335    168.340581
# Name: ArrDelay, dtype: float64
# Error:  336    5.009912
# Name: ArrDelay, dtype: float64
# Error:  337    22.061449
# Name: ArrDelay, dtype: float64
# Error:  338    563.694879
# Name: ArrDelay, dtype: float64
# Error:  339    2.226065
# Name: ArrDelay, dtype: float64
# Error:  340    0.24933
# Name: ArrDelay, dtype: float64
# Error:  341    1.131128
# Name: ArrDelay, dtype: float64
# Error:  342    108.977963
# Name: ArrDelay, dtype: float64
# Error:  343    0.448871
# Name: ArrDelay, dtype: float64
# Error:  344    179.332145
# Name: ArrDelay, dtype: float64
# Error:  345    52.717029
# Name: ArrDelay, dtype: float64
# Error:  346    602.080654
# Name: ArrDelay, dtype: float64
# Error:  347    9.043771
# Name: ArrDelay, dtype: float64
# Error:  348    44.650448
# Name: ArrDelay, dtype: float64
# Error:  349    0.274333
# Name: ArrDelay, dtype: float64
# Error:  350    36.838299
# Name: ArrDelay, dtype: float64
# Error:  351    23.206225
# Name: ArrDelay, dtype: float64
# Error:  352    99.827277
# Name: ArrDelay, dtype: float64
# Error:  353    12.950089
# Name: ArrDelay, dtype: float64
# Error:  354    114.205285
# Name: ArrDelay, dtype: float64
# Error:  355    18.220747
# Name: ArrDelay, dtype: float64
# Error:  356    364.447417
# Name: ArrDelay, dtype: float64
# Error:  357    9.280828
# Name: ArrDelay, dtype: float64
# Error:  358    13.347411
# Name: ArrDelay, dtype: float64
# Error:  359    0.587598
# Name: ArrDelay, dtype: float64
# Error:  360    153.86438
# Name: ArrDelay, dtype: float64
# Error:  361    21.234046
# Name: ArrDelay, dtype: float64
# Error:  362    4.147667
# Name: ArrDelay, dtype: float64
# Error:  363    9.888391
# Name: ArrDelay, dtype: float64
# Error:  364    87.174359
# Name: ArrDelay, dtype: float64
# Error:  365    37.020843
# Name: ArrDelay, dtype: float64
# Error:  366    115.193109
# Name: ArrDelay, dtype: float64
# Error:  367    8.151371
# Name: ArrDelay, dtype: float64
# Error:  368    6.074368
# Name: ArrDelay, dtype: float64
# Error:  369    201.274601
# Name: ArrDelay, dtype: float64
# Error:  370    4.625065
# Name: ArrDelay, dtype: float64
# Error:  371    199.370762
# Name: ArrDelay, dtype: float64
# Error:  372    94.565006
# Name: ArrDelay, dtype: float64
# Error:  373    37.228642
# Name: ArrDelay, dtype: float64
# Error:  374    0.988242
# Name: ArrDelay, dtype: float64
# Error:  375    72.134474
# Name: ArrDelay, dtype: float64
# Error:  376    58.330777
# Name: ArrDelay, dtype: float64
# Error:  377    0.48602
# Name: ArrDelay, dtype: float64
# Error:  378    147.237505
# Name: ArrDelay, dtype: float64
# Error:  379    1199.905368
# Name: ArrDelay, dtype: float64
# Error:  380    21.051796
# Name: ArrDelay, dtype: float64
# Error:  381    20.889997
# Name: ArrDelay, dtype: float64
# Error:  382    49.521983
# Name: ArrDelay, dtype: float64
# Error:  383    0.243799
# Name: ArrDelay, dtype: float64
# Error:  384    1.889629
# Name: ArrDelay, dtype: float64
# Error:  385    7.187379
# Name: ArrDelay, dtype: float64
# Error:  386    332.590932
# Name: ArrDelay, dtype: float64
# Error:  387    344.593048
# Name: ArrDelay, dtype: float64
# Error:  388    169.891903
# Name: ArrDelay, dtype: float64
# Error:  389    179.647372
# Name: ArrDelay, dtype: float64
# Error:  390    447.835789
# Name: ArrDelay, dtype: float64
# Error:  391    40.808173
# Name: ArrDelay, dtype: float64
# Error:  392    27.811851
# Name: ArrDelay, dtype: float64
# Error:  393    97.411548
# Name: ArrDelay, dtype: float64
# Error:  394    368.521471
# Name: ArrDelay, dtype: float64
# Error:  395    11.051475
# Name: ArrDelay, dtype: float64
# Error:  396    0.004524
# Name: ArrDelay, dtype: float64
# Error:  397    0.010688
# Name: ArrDelay, dtype: float64
# Error:  398    28.42356
# Name: ArrDelay, dtype: float64
# Error:  399    248.696501
# Name: ArrDelay, dtype: float64
# Error:  400    351.237583
# Name: ArrDelay, dtype: float64
# Error:  401    6.584374
# Name: ArrDelay, dtype: float64
# Error:  402    60.276783
# Name: ArrDelay, dtype: float64
# Error:  403    39.795542
# Name: ArrDelay, dtype: float64
# Error:  404    10.898266
# Name: ArrDelay, dtype: float64
# Error:  405    443.050347
# Name: ArrDelay, dtype: float64
# Error:  406    107.141068
# Name: ArrDelay, dtype: float64
# Error:  407    83.028331
# Name: ArrDelay, dtype: float64
# Error:  408    0.795627
# Name: ArrDelay, dtype: float64
# Error:  409    5.312798
# Name: ArrDelay, dtype: float64
# Error:  410    36.266454
# Name: ArrDelay, dtype: float64
# Error:  411    30.367477
# Name: ArrDelay, dtype: float64
# Error:  412    13.273781
# Name: ArrDelay, dtype: float64
# Error:  413    39.214046
# Name: ArrDelay, dtype: float64
# Error:  414    3.268886
# Name: ArrDelay, dtype: float64
# Error:  415    134.677437
# Name: ArrDelay, dtype: float64
# Error:  416    230.683764
# Name: ArrDelay, dtype: float64
# Error:  417    89.151008
# Name: ArrDelay, dtype: float64
# Error:  418    10.742373
# Name: ArrDelay, dtype: float64
# Error:  419    9.242302
# Name: ArrDelay, dtype: float64
# Error:  420    0.126987
# Name: ArrDelay, dtype: float64
# Error:  421    0.390428
# Name: ArrDelay, dtype: float64
# Error:  422    0.214029
# Name: ArrDelay, dtype: float64
# Error:  423    20.017399
# Name: ArrDelay, dtype: float64
# Error:  424    47.762601
# Name: ArrDelay, dtype: float64
# Error:  425    720.753546
# Name: ArrDelay, dtype: float64
# Error:  426    39.705181
# Name: ArrDelay, dtype: float64
# Error:  427    0.159616
# Name: ArrDelay, dtype: float64
# Error:  428    66.068917
# Name: ArrDelay, dtype: float64
# Error:  429    0.001794
# Name: ArrDelay, dtype: float64
# Error:  430    4.235895
# Name: ArrDelay, dtype: float64
# Error:  431    3.4873
# Name: ArrDelay, dtype: float64
# Error:  432    17.36353
# Name: ArrDelay, dtype: float64
# Error:  433    611.867048
# Name: ArrDelay, dtype: float64
# Error:  434    16.141565
# Name: ArrDelay, dtype: float64
# Error:  435    5.058512
# Name: ArrDelay, dtype: float64
# Error:  436    74.012661
# Name: ArrDelay, dtype: float64
# Error:  437    665.187714
# Name: ArrDelay, dtype: float64
# Error:  438    352.785398
# Name: ArrDelay, dtype: float64
# Error:  439    5.849601
# Name: ArrDelay, dtype: float64
# Error:  440    4.682835
# Name: ArrDelay, dtype: float64
# Error:  441    54.201399
# Name: ArrDelay, dtype: float64
# Error:  442    193.160229
# Name: ArrDelay, dtype: float64
# Error:  443    2.468507
# Name: ArrDelay, dtype: float64
# Error:  444    381.303819
# Name: ArrDelay, dtype: float64
# Error:  445    309.573406
# Name: ArrDelay, dtype: float64
# Error:  446    9.109653
# Name: ArrDelay, dtype: float64
# Error:  447    194.483517
# Name: ArrDelay, dtype: float64
# Error:  448    218.679587
# Name: ArrDelay, dtype: float64
# Error:  449    165.688529
# Name: ArrDelay, dtype: float64
# Error:  450    4.921271
# Name: ArrDelay, dtype: float64
# Error:  451    4.518704
# Name: ArrDelay, dtype: float64
# Error:  452    0.363976
# Name: ArrDelay, dtype: float64
# Error:  453    0.001733
# Name: ArrDelay, dtype: float64
# Error:  454    51.53872
# Name: ArrDelay, dtype: float64
# Error:  455    359.987745
# Name: ArrDelay, dtype: float64
# Error:  456    133.781373
# Name: ArrDelay, dtype: float64
# Error:  457    25.779393
# Name: ArrDelay, dtype: float64
# Error:  458    23.672689
# Name: ArrDelay, dtype: float64
# Error:  459    1713.020428
# Name: ArrDelay, dtype: float64
# Error:  460    58.276501
# Name: ArrDelay, dtype: float64
# Error:  461    325.763437
# Name: ArrDelay, dtype: float64
# Error:  462    433.914348
# Name: ArrDelay, dtype: float64
# Error:  463    73.88957
# Name: ArrDelay, dtype: float64
# Error:  464    168.250032
# Name: ArrDelay, dtype: float64
# Error:  465    3.201894
# Name: ArrDelay, dtype: float64
# Error:  466    0.012654
# Name: ArrDelay, dtype: float64
# Error:  467    77.641086
# Name: ArrDelay, dtype: float64
# Error:  468    651.348591
# Name: ArrDelay, dtype: float64
# Error:  469    98.266059
# Name: ArrDelay, dtype: float64
# Error:  470    11.377217
# Name: ArrDelay, dtype: float64
# Error:  471    0.787733
# Name: ArrDelay, dtype: float64
# Error:  472    978.060539
# Name: ArrDelay, dtype: float64
# Error:  473    328.581626
# Name: ArrDelay, dtype: float64
# Error:  474    454.324669
# Name: ArrDelay, dtype: float64
# Error:  475    46.846662
# Name: ArrDelay, dtype: float64
# Error:  476    165.673742
# Name: ArrDelay, dtype: float64
# Error:  477    30.455397
# Name: ArrDelay, dtype: float64
# Error:  478    202.918027
# Name: ArrDelay, dtype: float64
# Error:  479    112.542948
# Name: ArrDelay, dtype: float64
# Error:  480    0.390612
# Name: ArrDelay, dtype: float64
# Error:  481    6.654253
# Name: ArrDelay, dtype: float64
# Error:  482    2.516205
# Name: ArrDelay, dtype: float64
# Error:  483    513.948408
# Name: ArrDelay, dtype: float64
# Error:  484    4.169598
# Name: ArrDelay, dtype: float64
# Error:  485    14.026559
# Name: ArrDelay, dtype: float64
# Error:  486    149.210962
# Name: ArrDelay, dtype: float64
# Error:  487    1.291299
# Name: ArrDelay, dtype: float64
# Error:  488    1.668364
# Name: ArrDelay, dtype: float64
# Error:  489    408.953053
# Name: ArrDelay, dtype: float64
# Error:  490    33.425212
# Name: ArrDelay, dtype: float64
# Error:  491    180.293796
# Name: ArrDelay, dtype: float64
# Error:  492    0.115205
# Name: ArrDelay, dtype: float64
# Error:  493    242.722596
# Name: ArrDelay, dtype: float64
# Error:  494    212.551205
# Name: ArrDelay, dtype: float64
# Error:  495    35.842406
# Name: ArrDelay, dtype: float64
# Error:  496    122.569251
# Name: ArrDelay, dtype: float64
# Error:  497    37.852545
# Name: ArrDelay, dtype: float64
# Error:  498    0.896106
# Name: ArrDelay, dtype: float64
# Error:  499    0.008305
# Name: ArrDelay, dtype: float64
# Error:  500    1012.802337
# Name: ArrDelay, dtype: float64
# Error:  501    6.695126
# Name: ArrDelay, dtype: float64
# Error:  502    6.580423
# Name: ArrDelay, dtype: float64
# Error:  503    139.790136
# Name: ArrDelay, dtype: float64
# Error:  504    132.627699
# Name: ArrDelay, dtype: float64
# Error:  505    0.375901
# Name: ArrDelay, dtype: float64
# Error:  506    4.462237
# Name: ArrDelay, dtype: float64
# Error:  507    6.09751
# Name: ArrDelay, dtype: float64
# Error:  508    35.89541
# Name: ArrDelay, dtype: float64
# Error:  509    0.000362
# Name: ArrDelay, dtype: float64
# Error:  510    177.24987
# Name: ArrDelay, dtype: float64
# Error:  511    4051.040186
# Name: ArrDelay, dtype: float64
# Error:  512    95.88989
# Name: ArrDelay, dtype: float64
# Error:  513    21.46711
# Name: ArrDelay, dtype: float64
# Error:  514    257.808864
# Name: ArrDelay, dtype: float64
# Error:  515    24.641752
# Name: ArrDelay, dtype: float64
# Error:  516    178.761687
# Name: ArrDelay, dtype: float64
# Error:  517    8.527891
# Name: ArrDelay, dtype: float64
# Error:  518    18.544877
# Name: ArrDelay, dtype: float64
# Error:  519    0.125226
# Name: ArrDelay, dtype: float64
# Error:  520    1.879111
# Name: ArrDelay, dtype: float64
# Error:  521    14.305292
# Name: ArrDelay, dtype: float64
# Error:  522    0.974127
# Name: ArrDelay, dtype: float64
# Error:  523    32.171891
# Name: ArrDelay, dtype: float64
# Error:  524    17.357094
# Name: ArrDelay, dtype: float64
# Error:  525    25.666014
# Name: ArrDelay, dtype: float64
# Error:  526    31.569437
# Name: ArrDelay, dtype: float64
# Error:  527    20.218423
# Name: ArrDelay, dtype: float64
# Error:  528    149.078717
# Name: ArrDelay, dtype: float64
# Error:  529    50.259303
# Name: ArrDelay, dtype: float64
# Error:  530    431.879987
# Name: ArrDelay, dtype: float64
# Error:  531    2.557857
# Name: ArrDelay, dtype: float64
# Error:  532    36.936264
# Name: ArrDelay, dtype: float64
# Error:  533    8.731234
# Name: ArrDelay, dtype: float64
# Error:  534    22.87795
# Name: ArrDelay, dtype: float64
# Error:  535    4.376695
# Name: ArrDelay, dtype: float64
# Error:  536    18.020142
# Name: ArrDelay, dtype: float64
# Error:  537    299.188998
# Name: ArrDelay, dtype: float64
# Error:  538    26.84887
# Name: ArrDelay, dtype: float64
# Error:  539    261.054016
# Name: ArrDelay, dtype: float64
# Error:  540    103.922957
# Name: ArrDelay, dtype: float64
# Error:  541    0.15569
# Name: ArrDelay, dtype: float64
# Error:  542    73.118911
# Name: ArrDelay, dtype: float64
# Error:  543    143.0826
# Name: ArrDelay, dtype: float64
# Error:  544    944.151552
# Name: ArrDelay, dtype: float64
# Error:  545    128.434251
# Name: ArrDelay, dtype: float64
# Error:  546    334.114737
# Name: ArrDelay, dtype: float64
# Error:  547    3.066856
# Name: ArrDelay, dtype: float64
# Error:  548    0.135888
# Name: ArrDelay, dtype: float64
# Error:  549    1.115364
# Name: ArrDelay, dtype: float64
# Error:  550    217.732577
# Name: ArrDelay, dtype: float64
# Error:  551    9.834375
# Name: ArrDelay, dtype: float64
# Error:  552    16.560642
# Name: ArrDelay, dtype: float64
# Error:  553    8.48252
# Name: ArrDelay, dtype: float64
# Error:  554    11.527227
# Name: ArrDelay, dtype: float64
# Error:  555    43.954954
# Name: ArrDelay, dtype: float64
# Error:  556    105.045597
# Name: ArrDelay, dtype: float64
# Error:  557    256.758588
# Name: ArrDelay, dtype: float64
# Error:  558    0.138051
# Name: ArrDelay, dtype: float64
# Error:  559    78.177943
# Name: ArrDelay, dtype: float64
# Error:  560    3.071771
# Name: ArrDelay, dtype: float64
# Error:  561    365.587144
# Name: ArrDelay, dtype: float64
# Error:  562    24.094249
# Name: ArrDelay, dtype: float64
# Error:  563    335.868245
# Name: ArrDelay, dtype: float64
# Error:  564    1.571853
# Name: ArrDelay, dtype: float64
# Error:  565    134.457224
# Name: ArrDelay, dtype: float64
# Error:  566    277.576993
# Name: ArrDelay, dtype: float64
# Error:  567    23.991996
# Name: ArrDelay, dtype: float64
# Error:  568    8.532599
# Name: ArrDelay, dtype: float64
# Error:  569    40.32789
# Name: ArrDelay, dtype: float64
# Error:  570    62.422001
# Name: ArrDelay, dtype: float64
# Error:  571    32.399064
# Name: ArrDelay, dtype: float64
# Error:  572    1.049401
# Name: ArrDelay, dtype: float64
# Error:  573    26.595458
# Name: ArrDelay, dtype: float64
# Error:  574    9.686107
# Name: ArrDelay, dtype: float64
# Error:  575    0.016176
# Name: ArrDelay, dtype: float64
# Error:  576    6.074141
# Name: ArrDelay, dtype: float64
# Error:  577    1.37753
# Name: ArrDelay, dtype: float64
# Error:  578    11.228174
# Name: ArrDelay, dtype: float64
# Error:  579    67.235991
# Name: ArrDelay, dtype: float64
# Error:  580    70.482024
# Name: ArrDelay, dtype: float64
# Error:  581    167.503249
# Name: ArrDelay, dtype: float64
# Error:  582    252.38861
# Name: ArrDelay, dtype: float64
# Error:  583    998.709118
# Name: ArrDelay, dtype: float64
# Error:  584    4.591831
# Name: ArrDelay, dtype: float64
# Error:  585    1.033196
# Name: ArrDelay, dtype: float64
# Error:  586    7.79606
# Name: ArrDelay, dtype: float64
# Error:  587    19.735288
# Name: ArrDelay, dtype: float64
# Error:  588    344.18243
# Name: ArrDelay, dtype: float64
# Error:  589    281.552898
# Name: ArrDelay, dtype: float64
# Error:  590    110.96067
# Name: ArrDelay, dtype: float64
# Error:  591    209.916012
# Name: ArrDelay, dtype: float64
# Error:  592    190.366651
# Name: ArrDelay, dtype: float64
# Error:  593    216.754861
# Name: ArrDelay, dtype: float64
# Error:  594    4.251119
# Name: ArrDelay, dtype: float64
# Error:  595    10.794753
# Name: ArrDelay, dtype: float64
# Error:  596    293.53696
# Name: ArrDelay, dtype: float64
# Error:  597    16.860726
# Name: ArrDelay, dtype: float64
# Error:  598    16.828229
# Name: ArrDelay, dtype: float64
# Error:  599    1.616862
# Name: ArrDelay, dtype: float64
# Error:  600    150.273185
# Name: ArrDelay, dtype: float64
# Error:  601    39.696269
# Name: ArrDelay, dtype: float64
# Error:  602    20.237068
# Name: ArrDelay, dtype: float64
# Error:  603    1.136911
# Name: ArrDelay, dtype: float64
# Error:  604    35.579332
# Name: ArrDelay, dtype: float64
# Error:  605    12.064299
# Name: ArrDelay, dtype: float64
# Error:  606    43.260149
# Name: ArrDelay, dtype: float64
# Error:  607    18.23424
# Name: ArrDelay, dtype: float64
# Error:  608    27.765649
# Name: ArrDelay, dtype: float64
# Error:  609    52.000001
# Name: ArrDelay, dtype: float64
# Error:  610    25.844105
# Name: ArrDelay, dtype: float64
# Error:  611    54.550418
# Name: ArrDelay, dtype: float64
# Error:  612    72.746369
# Name: ArrDelay, dtype: float64
# Error:  613    2.234472
# Name: ArrDelay, dtype: float64
# Error:  614    6.03846
# Name: ArrDelay, dtype: float64
# Error:  615    65.522233
# Name: ArrDelay, dtype: float64
# Error:  616    0.02414
# Name: ArrDelay, dtype: float64
# Error:  617    59.601407
# Name: ArrDelay, dtype: float64
# Error:  618    572.158362
# Name: ArrDelay, dtype: float64
# Error:  619    86.65875
# Name: ArrDelay, dtype: float64
# Error:  620    72.304225
# Name: ArrDelay, dtype: float64
# Error:  621    3.272549
# Name: ArrDelay, dtype: float64
# Error:  622    200.360281
# Name: ArrDelay, dtype: float64
# Error:  623    138.15891
# Name: ArrDelay, dtype: float64
# Error:  624    26.623852
# Name: ArrDelay, dtype: float64
# Error:  625    9.444499
# Name: ArrDelay, dtype: float64
# Error:  626    149.528692
# Name: ArrDelay, dtype: float64
# Error:  627    6.920368
# Name: ArrDelay, dtype: float64
# Error:  628    0.443819
# Name: ArrDelay, dtype: float64
# Error:  629    23.95648
# Name: ArrDelay, dtype: float64
# Error:  630    13.243163
# Name: ArrDelay, dtype: float64
# Error:  631    39.783994
# Name: ArrDelay, dtype: float64
# Error:  632    101.048794
# Name: ArrDelay, dtype: float64
# Error:  633    2.686796
# Name: ArrDelay, dtype: float64
# Error:  634    2.205692
# Name: ArrDelay, dtype: float64
# Error:  635    109.031724
# Name: ArrDelay, dtype: float64
# Error:  636    4.101641
# Name: ArrDelay, dtype: float64
# Error:  637    92.831621
# Name: ArrDelay, dtype: float64
# Error:  638    11.362794
# Name: ArrDelay, dtype: float64
# Error:  639    32.795798
# Name: ArrDelay, dtype: float64
# Error:  640    0.568216
# Name: ArrDelay, dtype: float64
# Error:  641    429.507015
# Name: ArrDelay, dtype: float64
# Error:  642    111.299565
# Name: ArrDelay, dtype: float64
# Error:  643    545.340244
# Name: ArrDelay, dtype: float64
# Error:  644    0.792333
# Name: ArrDelay, dtype: float64
# Error:  645    6.698489
# Name: ArrDelay, dtype: float64
# Error:  646    311.313537
# Name: ArrDelay, dtype: float64
# Error:  647    0.069759
# Name: ArrDelay, dtype: float64
# Error:  648    31.417048
# Name: ArrDelay, dtype: float64
# Error:  649    46.140849
# Name: ArrDelay, dtype: float64
# Error:  650    105.527675
# Name: ArrDelay, dtype: float64
# Error:  651    31.616253
# Name: ArrDelay, dtype: float64
# Error:  652    170.269319
# Name: ArrDelay, dtype: float64
# Error:  653    29.30875
# Name: ArrDelay, dtype: float64
# Error:  654    225.888532
# Name: ArrDelay, dtype: float64
# Error:  655    29.960858
# Name: ArrDelay, dtype: float64
# Error:  656    84.708775
# Name: ArrDelay, dtype: float64
# Error:  657    12.789774
# Name: ArrDelay, dtype: float64
# Error:  658    786.291786
# Name: ArrDelay, dtype: float64
# Error:  659    7.199559
# Name: ArrDelay, dtype: float64
# Error:  660    0.442405
# Name: ArrDelay, dtype: float64
# Error:  661    3.641928
# Name: ArrDelay, dtype: float64
# Error:  662    0.566306
# Name: ArrDelay, dtype: float64
# Error:  663    2.099761
# Name: ArrDelay, dtype: float64
# Error:  664    16.332537
# Name: ArrDelay, dtype: float64
# Error:  665    1523.099237
# Name: ArrDelay, dtype: float64
# Error:  666    44.132037
# Name: ArrDelay, dtype: float64
# Error:  667    631.054345
# Name: ArrDelay, dtype: float64
# Error:  668    70.269003
# Name: ArrDelay, dtype: float64
# Error:  669    121.356445
# Name: ArrDelay, dtype: float64
# Error:  670    47.49968
# Name: ArrDelay, dtype: float64
# Error:  671    394.304818
# Name: ArrDelay, dtype: float64
# Error:  672    9.036068
# Name: ArrDelay, dtype: float64
# Error:  673    239.968704
# Name: ArrDelay, dtype: float64
# Error:  674    69.562461
# Name: ArrDelay, dtype: float64
# Error:  675    49.600981
# Name: ArrDelay, dtype: float64
# Error:  676    33.800962
# Name: ArrDelay, dtype: float64
# Error:  677    4.35595
# Name: ArrDelay, dtype: float64
# Error:  678    4.923528
# Name: ArrDelay, dtype: float64
# Error:  679    13.865724
# Name: ArrDelay, dtype: float64
# Error:  680    187.609261
# Name: ArrDelay, dtype: float64
# Error:  681    11.853056
# Name: ArrDelay, dtype: float64
# Error:  682    1.624229
# Name: ArrDelay, dtype: float64
# Error:  683    9.788785
# Name: ArrDelay, dtype: float64
# Error:  684    6.400055
# Name: ArrDelay, dtype: float64
# Error:  685    23.644857
# Name: ArrDelay, dtype: float64
# Error:  686    139.323033
# Name: ArrDelay, dtype: float64
# Error:  687    1.739591
# Name: ArrDelay, dtype: float64
# Error:  688    78.427209
# Name: ArrDelay, dtype: float64
# Error:  689    34.081964
# Name: ArrDelay, dtype: float64
# Error:  690    70.323074
# Name: ArrDelay, dtype: float64
# Error:  691    2.179965
# Name: ArrDelay, dtype: float64
# Error:  692    1.510938
# Name: ArrDelay, dtype: float64
# Error:  693    31.55853
# Name: ArrDelay, dtype: float64
# Error:  694    41.256287
# Name: ArrDelay, dtype: float64
# Error:  695    79.337377
# Name: ArrDelay, dtype: float64
# Error:  696    35.101664
# Name: ArrDelay, dtype: float64
# Error:  697    19.852051
# Name: ArrDelay, dtype: float64
# Error:  698    42.1057
# Name: ArrDelay, dtype: float64
# Error:  699    0.345706
# Name: ArrDelay, dtype: float64
# Error:  700    43.460683
# Name: ArrDelay, dtype: float64
# Error:  701    4.589286
# Name: ArrDelay, dtype: float64
# Error:  702    2.489853
# Name: ArrDelay, dtype: float64
# Error:  703    0.260573
# Name: ArrDelay, dtype: float64
# Error:  704    67.881936
# Name: ArrDelay, dtype: float64
# Error:  705    24.553718
# Name: ArrDelay, dtype: float64
# Error:  706    23.702313
# Name: ArrDelay, dtype: float64
# Error:  707    1.9069
# Name: ArrDelay, dtype: float64
# Error:  708    18.133754
# Name: ArrDelay, dtype: float64
# Error:  709    10.399325
# Name: ArrDelay, dtype: float64
# Error:  710    29.807962
# Name: ArrDelay, dtype: float64
# Error:  711    6.279201
# Name: ArrDelay, dtype: float64
# Error:  712    124.329161
# Name: ArrDelay, dtype: float64
# Error:  713    58.880723
# Name: ArrDelay, dtype: float64
# Error:  714    336.339561
# Name: ArrDelay, dtype: float64
# Error:  715    12.373768
# Name: ArrDelay, dtype: float64
# Error:  716    114.499837
# Name: ArrDelay, dtype: float64
# Error:  717    12.837489
# Name: ArrDelay, dtype: float64
# Error:  718    727.685069
# Name: ArrDelay, dtype: float64
# Error:  719    0.797405
# Name: ArrDelay, dtype: float64
# Error:  720    6.574111
# Name: ArrDelay, dtype: float64
# Error:  721    9.90672
# Name: ArrDelay, dtype: float64
# Error:  722    290.635837
# Name: ArrDelay, dtype: float64
# Error:  723    745.758701
# Name: ArrDelay, dtype: float64
# Error:  724    80.08299
# Name: ArrDelay, dtype: float64
# Error:  725    99.165656
# Name: ArrDelay, dtype: float64
# Error:  726    237.106595
# Name: ArrDelay, dtype: float64
# Error:  727    20.5554
# Name: ArrDelay, dtype: float64
# Error:  728    0.050882
# Name: ArrDelay, dtype: float64
# Error:  729    283.223096
# Name: ArrDelay, dtype: float64
# Error:  730    56.267656
# Name: ArrDelay, dtype: float64
# Error:  731    34.852659
# Name: ArrDelay, dtype: float64
# Error:  732    157.858291
# Name: ArrDelay, dtype: float64
# Error:  733    443.198703
# Name: ArrDelay, dtype: float64
# Error:  734    387.815687
# Name: ArrDelay, dtype: float64
# Error:  735    150.895548
# Name: ArrDelay, dtype: float64
# Error:  736    340.24846
# Name: ArrDelay, dtype: float64
# Error:  737    27.20862
# Name: ArrDelay, dtype: float64
# Error:  738    133.405541
# Name: ArrDelay, dtype: float64
# Error:  739    529.49182
# Name: ArrDelay, dtype: float64
# Error:  740    4.881418
# Name: ArrDelay, dtype: float64
# Error:  741    2.201679
# Name: ArrDelay, dtype: float64
# Error:  742    11.546591
# Name: ArrDelay, dtype: float64
# Error:  743    265.090238
# Name: ArrDelay, dtype: float64
# Error:  744    4.96762
# Name: ArrDelay, dtype: float64
# Error:  745    37.329743
# Name: ArrDelay, dtype: float64
# Error:  746    123.674397
# Name: ArrDelay, dtype: float64
# Error:  747    2.89354
# Name: ArrDelay, dtype: float64
# Error:  748    95.616296
# Name: ArrDelay, dtype: float64
# Error:  749    51.950844
# Name: ArrDelay, dtype: float64
# Error:  750    141.310717
# Name: ArrDelay, dtype: float64
# Error:  751    40.692119
# Name: ArrDelay, dtype: float64
# Error:  752    3.573873
# Name: ArrDelay, dtype: float64
# Error:  753    163.031281
# Name: ArrDelay, dtype: float64
# Error:  754    6.318156
# Name: ArrDelay, dtype: float64
# Error:  755    181.730666
# Name: ArrDelay, dtype: float64
# Error:  756    22.430184
# Name: ArrDelay, dtype: float64
# Error:  757    119.283644
# Name: ArrDelay, dtype: float64
# Error:  758    762.414745
# Name: ArrDelay, dtype: float64
# Error:  759    0.095137
# Name: ArrDelay, dtype: float64
# Error:  760    156.346036
# Name: ArrDelay, dtype: float64
# Error:  761    557.392979
# Name: ArrDelay, dtype: float64
# Error:  762    19.746187
# Name: ArrDelay, dtype: float64
# Error:  763    2.156789
# Name: ArrDelay, dtype: float64
# Error:  764    228.285743
# Name: ArrDelay, dtype: float64
# Error:  765    51.561348
# Name: ArrDelay, dtype: float64
# Error:  766    12.38406
# Name: ArrDelay, dtype: float64
# Error:  767    52.722394
# Name: ArrDelay, dtype: float64
# Error:  768    20.143754
# Name: ArrDelay, dtype: float64
# Error:  769    26.791912
# Name: ArrDelay, dtype: float64
# Error:  770    358.197933
# Name: ArrDelay, dtype: float64
# Error:  771    1.177902
# Name: ArrDelay, dtype: float64
# Error:  772    719.614233
# Name: ArrDelay, dtype: float64
# Error:  773    133.436577
# Name: ArrDelay, dtype: float64
# Error:  774    12.822492
# Name: ArrDelay, dtype: float64
# Error:  775    109.287948
# Name: ArrDelay, dtype: float64
# Error:  776    527.275737
# Name: ArrDelay, dtype: float64
# Error:  777    0.743119
# Name: ArrDelay, dtype: float64
# Error:  778    26.353339
# Name: ArrDelay, dtype: float64
# Error:  779    359.242123
# Name: ArrDelay, dtype: float64
# Error:  780    254.735396
# Name: ArrDelay, dtype: float64
# Error:  781    70.527308
# Name: ArrDelay, dtype: float64
# Error:  782    113.952948
# Name: ArrDelay, dtype: float64
# Error:  783    80.88363
# Name: ArrDelay, dtype: float64
# Error:  784    330.352916
# Name: ArrDelay, dtype: float64
# Error:  785    127.918127
# Name: ArrDelay, dtype: float64
# Error:  786    153.861068
# Name: ArrDelay, dtype: float64
# Error:  787    7.592226
# Name: ArrDelay, dtype: float64
# Error:  788    2882.250387
# Name: ArrDelay, dtype: float64
# Error:  789    517.165618
# Name: ArrDelay, dtype: float64
# Error:  790    0.475076
# Name: ArrDelay, dtype: float64
# Error:  791    285.908674
# Name: ArrDelay, dtype: float64
# Error:  792    54.120078
# Name: ArrDelay, dtype: float64
# Error:  793    3157.124163
# Name: ArrDelay, dtype: float64
# Error:  794    62.165869
# Name: ArrDelay, dtype: float64
# Error:  795    159.366332
# Name: ArrDelay, dtype: float64
# Error:  796    21.844054
# Name: ArrDelay, dtype: float64
# Error:  797    10.99403
# Name: ArrDelay, dtype: float64
# Error:  798    195.20822
# Name: ArrDelay, dtype: float64
# Error:  799    385.287386
# Name: ArrDelay, dtype: float64
# Error:  800    3159.309911
# Name: ArrDelay, dtype: float64
# Error:  801    4.276457
# Name: ArrDelay, dtype: float64
# Error:  802    135.375432
# Name: ArrDelay, dtype: float64
# Error:  803    322.761668
# Name: ArrDelay, dtype: float64
# Error:  804    0.002919
# Name: ArrDelay, dtype: float64
# Error:  805    551.773026
# Name: ArrDelay, dtype: float64
# Error:  806    21.611225
# Name: ArrDelay, dtype: float64
# Error:  807    44.958631
# Name: ArrDelay, dtype: float64
# Error:  808    265.631149
# Name: ArrDelay, dtype: float64
# Error:  809    8.100852
# Name: ArrDelay, dtype: float64
# Error:  810    75.32671
# Name: ArrDelay, dtype: float64
# Error:  811    137.133743
# Name: ArrDelay, dtype: float64
# Error:  812    39.501922
# Name: ArrDelay, dtype: float64
# Error:  813    82.272675
# Name: ArrDelay, dtype: float64
# Error:  814    151.357542
# Name: ArrDelay, dtype: float64
# Error:  815    107.885338
# Name: ArrDelay, dtype: float64
# Error:  816    38.83029
# Name: ArrDelay, dtype: float64
# Error:  817    533.579134
# Name: ArrDelay, dtype: float64
# Error:  818    7.240744
# Name: ArrDelay, dtype: float64
# Error:  819    215.405577
# Name: ArrDelay, dtype: float64
# Error:  820    7.687144
# Name: ArrDelay, dtype: float64
# Error:  821    121.249214
# Name: ArrDelay, dtype: float64
# Error:  822    1.381984
# Name: ArrDelay, dtype: float64
# Error:  823    54.560476
# Name: ArrDelay, dtype: float64
# Error:  824    88.730409
# Name: ArrDelay, dtype: float64
# Error:  825    4.449007
# Name: ArrDelay, dtype: float64
# Error:  826    0.062284
# Name: ArrDelay, dtype: float64
# Error:  827    29.36583
# Name: ArrDelay, dtype: float64
# Error:  828    2.010712
# Name: ArrDelay, dtype: float64
# Error:  829    113.836039
# Name: ArrDelay, dtype: float64
# Error:  830    6.440898
# Name: ArrDelay, dtype: float64
# Error:  831    0.020593
# Name: ArrDelay, dtype: float64
# Error:  832    33.703262
# Name: ArrDelay, dtype: float64
# Error:  833    2.829886
# Name: ArrDelay, dtype: float64
# Error:  834    60.311725
# Name: ArrDelay, dtype: float64
# Error:  835    237.556603
# Name: ArrDelay, dtype: float64
# Error:  836    14.086889
# Name: ArrDelay, dtype: float64
# Error:  837    0.012757
# Name: ArrDelay, dtype: float64
# Error:  838    28.667549
# Name: ArrDelay, dtype: float64
# Error:  839    19.509774
# Name: ArrDelay, dtype: float64
# Error:  840    28.616762
# Name: ArrDelay, dtype: float64
# Error:  841    139.583775
# Name: ArrDelay, dtype: float64
# Error:  842    42.279971
# Name: ArrDelay, dtype: float64
# Error:  843    137.931272
# Name: ArrDelay, dtype: float64
# Error:  844    7.309868
# Name: ArrDelay, dtype: float64
# Error:  845    90.710377
# Name: ArrDelay, dtype: float64
# Error:  846    45.219976
# Name: ArrDelay, dtype: float64
# Error:  847    0.03547
# Name: ArrDelay, dtype: float64
# Error:  848    5.293729
# Name: ArrDelay, dtype: float64
# Error:  849    305.393219
# Name: ArrDelay, dtype: float64
# Error:  850    408.013138
# Name: ArrDelay, dtype: float64
# Error:  851    22.180379
# Name: ArrDelay, dtype: float64
# Error:  852    193.40235
# Name: ArrDelay, dtype: float64
# Error:  853    11.0164
# Name: ArrDelay, dtype: float64
# Error:  854    597.805038
# Name: ArrDelay, dtype: float64
# Error:  855    279.195717
# Name: ArrDelay, dtype: float64
# Error:  856    377.191195
# Name: ArrDelay, dtype: float64
# Error:  857    47.319054
# Name: ArrDelay, dtype: float64
# Error:  858    91.071538
# Name: ArrDelay, dtype: float64
# Error:  859    0.015173
# ...
# Error:  4719    14.730525
# Name: ArrDelay, dtype: float64
# Error:  4720    62.315755
# Name: ArrDelay, dtype: float64
# Error:  4721    69.5463
# Name: ArrDelay, dtype: float64
# Error:  4722    9.564208
# Name: ArrDelay, dtype: float64
# Error:  4723    44.294141
# Name: ArrDelay, dtype: float64
# Error:  4724    419.219009
# Name: ArrDelay, dtype: float64
# Error:  4725    59.582098
# Name: ArrDelay, dtype: float64
# Error:  4726    210.704606
# Name: ArrDelay, dtype: float64
# Error:  4727    1220.400186
# Name: ArrDelay, dtype: float64
# Error:  4728    90.445561
# Name: ArrDelay, dtype: float64
# Error:  4729    22.53861
# Name: ArrDelay, dtype: float64
# Error:  4730    23.475988
# Name: ArrDelay, dtype: float64
# Error:  4731    17.847447
# Name: ArrDelay, dtype: float64
# Error:  4732    39.493078
# Name: ArrDelay, dtype: float64
# Error:  4733    147.021047
# Name: ArrDelay, dtype: float64
# Error:  4734    0.000163
# Name: ArrDelay, dtype: float64
# Error:  4735    3.125149
# Name: ArrDelay, dtype: float64
# Error:  4736    93.331022
# Name: ArrDelay, dtype: float64
# Error:  4737    50.197609
# Name: ArrDelay, dtype: float64
# Error:  4738    200.927131
# Name: ArrDelay, dtype: float64
# Error:  4739    171.433377
# Name: ArrDelay, dtype: float64
# Error:  4740    10.383944
# Name: ArrDelay, dtype: float64
# Error:  4741    72.184085
# Name: ArrDelay, dtype: float64
# Error:  4742    271.437457
# Name: ArrDelay, dtype: float64
# Error:  4743    268.286072
# Name: ArrDelay, dtype: float64
# Error:  4744    373.145146
# Name: ArrDelay, dtype: float64
# Error:  4745    21.629815
# Name: ArrDelay, dtype: float64
# Error:  4746    1.259247
# Name: ArrDelay, dtype: float64
# Error:  4747    73.346718
# Name: ArrDelay, dtype: float64
# Error:  4748    148.3418
# Name: ArrDelay, dtype: float64
# Error:  4749    240.196489
# Name: ArrDelay, dtype: float64
# Error:  4750    55.732716
# Name: ArrDelay, dtype: float64
# Error:  4751    8.999011
# Name: ArrDelay, dtype: float64
# Error:  4752    6.663368
# Name: ArrDelay, dtype: float64
# Error:  4753    3.56715
# Name: ArrDelay, dtype: float64
# Error:  4754    23.896945
# Name: ArrDelay, dtype: float64
# Error:  4755    5.819263
# Name: ArrDelay, dtype: float64
# Error:  4756    0.817352
# Name: ArrDelay, dtype: float64
# Error:  4757    61.166044
# Name: ArrDelay, dtype: float64
# Error:  4758    80.839788
# Name: ArrDelay, dtype: float64
# Error:  4759    0.169287
# Name: ArrDelay, dtype: float64
# Error:  4760    27.948322
# Name: ArrDelay, dtype: float64
# Error:  4761    3.274749
# Name: ArrDelay, dtype: float64
# Error:  4762    51.421735
# Name: ArrDelay, dtype: float64
# Error:  4763    8220.851108
# Name: ArrDelay, dtype: float64
# Error:  4764    149.020863
# Name: ArrDelay, dtype: float64
# Error:  4765    9.470548
# Name: ArrDelay, dtype: float64
# Error:  4766    52.000564
# Name: ArrDelay, dtype: float64
# Error:  4767    1.353791
# Name: ArrDelay, dtype: float64
# Error:  4768    4.234151
# Name: ArrDelay, dtype: float64
# Error:  4769    17.132875
# Name: ArrDelay, dtype: float64
# Error:  4770    251.783542
# Name: ArrDelay, dtype: float64
# Error:  4771    664.559692
# Name: ArrDelay, dtype: float64
# Error:  4772    522.096038
# Name: ArrDelay, dtype: float64
# Error:  4773    92.849338
# Name: ArrDelay, dtype: float64
# Error:  4774    335.040566
# Name: ArrDelay, dtype: float64
# Error:  4775    5.618618
# Name: ArrDelay, dtype: float64
# Error:  4776    243.129128
# Name: ArrDelay, dtype: float64
# Error:  4777    23.051227
# Name: ArrDelay, dtype: float64
# Error:  4778    6.106474
# Name: ArrDelay, dtype: float64
# Error:  4779    284.052757
# Name: ArrDelay, dtype: float64
# Error:  4780    9.974806
# Name: ArrDelay, dtype: float64
# Error:  4781    149.125007
# Name: ArrDelay, dtype: float64
# Error:  4782    274.147462
# Name: ArrDelay, dtype: float64
# Error:  4783    247.503036
# Name: ArrDelay, dtype: float64
# Error:  4784    6.785696
# Name: ArrDelay, dtype: float64
# Error:  4785    4.19863
# Name: ArrDelay, dtype: float64
# Error:  4786    1368.492787
# Name: ArrDelay, dtype: float64
# Error:  4787    524.356824
# Name: ArrDelay, dtype: float64
# Error:  4788    17.177299
# Name: ArrDelay, dtype: float64
# Error:  4789    70.003965
# Name: ArrDelay, dtype: float64
# Error:  4790    118.887163
# Name: ArrDelay, dtype: float64
# Error:  4791    108.747097
# Name: ArrDelay, dtype: float64
# Error:  4792    48.25884
# Name: ArrDelay, dtype: float64
# Error:  4793    10.84694
# Name: ArrDelay, dtype: float64
# Error:  4794    4.217719
# Name: ArrDelay, dtype: float64
# Error:  4795    972.237489
# Name: ArrDelay, dtype: float64
# Error:  4796    46.293042
# Name: ArrDelay, dtype: float64
# Error:  4797    119.391779
# Name: ArrDelay, dtype: float64
# Error:  4798    90.38378
# Name: ArrDelay, dtype: float64
# Error:  4799    6.325446
# Name: ArrDelay, dtype: float64
# Error:  4800    367.790605
# Name: ArrDelay, dtype: float64
# Error:  4801    42.857959
# Name: ArrDelay, dtype: float64
# Error:  4802    47.768459
# Name: ArrDelay, dtype: float64
# Error:  4803    250.400773
# Name: ArrDelay, dtype: float64
# Error:  4804    173.153748
# Name: ArrDelay, dtype: float64
# Error:  4805    500.134037
# Name: ArrDelay, dtype: float64
# Error:  4806    1.848367
# Name: ArrDelay, dtype: float64
# Error:  4807    63.444342
# Name: ArrDelay, dtype: float64
# Error:  4808    40.411606
# Name: ArrDelay, dtype: float64
# Error:  4809    13.940904
# Name: ArrDelay, dtype: float64
# Error:  4810    2.496047
# Name: ArrDelay, dtype: float64
# Error:  4811    92.260463
# Name: ArrDelay, dtype: float64
# Error:  4812    57.58165
# Name: ArrDelay, dtype: float64
# Error:  4813    52.065728
# Name: ArrDelay, dtype: float64
# Error:  4814    84.343915
# Name: ArrDelay, dtype: float64
# Error:  4815    92.255758
# Name: ArrDelay, dtype: float64
# Error:  4816    5.628193
# Name: ArrDelay, dtype: float64
# Error:  4817    109.159314
# Name: ArrDelay, dtype: float64
# Error:  4818    13.338827
# Name: ArrDelay, dtype: float64
# Error:  4819    9.430437
# Name: ArrDelay, dtype: float64
# Error:  4820    434.580201
# Name: ArrDelay, dtype: float64
# Error:  4821    17.159889
# Name: ArrDelay, dtype: float64
# Error:  4822    9.29541
# Name: ArrDelay, dtype: float64
# Error:  4823    70.703041
# Name: ArrDelay, dtype: float64
# Error:  4824    33.91361
# Name: ArrDelay, dtype: float64
# Error:  4825    1.292907
# Name: ArrDelay, dtype: float64
# Error:  4826    25.487955
# Name: ArrDelay, dtype: float64
# Error:  4827    49.429012
# Name: ArrDelay, dtype: float64
# Error:  4828    73.33089
# Name: ArrDelay, dtype: float64
# Error:  4829    18.68495
# Name: ArrDelay, dtype: float64
# Error:  4830    425.803193
# Name: ArrDelay, dtype: float64
# Error:  4831    20.515173
# Name: ArrDelay, dtype: float64
# Error:  4832    97.356535
# Name: ArrDelay, dtype: float64
# Error:  4833    449.76533
# Name: ArrDelay, dtype: float64
# Error:  4834    164.389319
# Name: ArrDelay, dtype: float64
# Error:  4835    0.019574
# Name: ArrDelay, dtype: float64
# Error:  4836    570.573688
# Name: ArrDelay, dtype: float64
# Error:  4837    18659.072314
# Name: ArrDelay, dtype: float64
# Error:  4838    51.88746
# Name: ArrDelay, dtype: float64
# Error:  4839    48.766364
# Name: ArrDelay, dtype: float64
# Error:  4840    82.828325
# Name: ArrDelay, dtype: float64
# Error:  4841    0.518718
# Name: ArrDelay, dtype: float64
# Error:  4842    5.490011
# Name: ArrDelay, dtype: float64
# Error:  4843    55.728311
# Name: ArrDelay, dtype: float64
# Error:  4844    8.248306
# Name: ArrDelay, dtype: float64
# Error:  4845    37.495399
# Name: ArrDelay, dtype: float64
# Error:  4846    0.840656
# Name: ArrDelay, dtype: float64
# Error:  4847    0.003894
# Name: ArrDelay, dtype: float64
# Error:  4848    224.203144
# Name: ArrDelay, dtype: float64
# Error:  4849    19.765432
# Name: ArrDelay, dtype: float64
# Error:  4850    130.854994
# Name: ArrDelay, dtype: float64
# Error:  4851    2.140944
# Name: ArrDelay, dtype: float64
# Error:  4852    43.379792
# Name: ArrDelay, dtype: float64
# Error:  4853    49.146657
# Name: ArrDelay, dtype: float64
# Error:  4854    17.100101
# Name: ArrDelay, dtype: float64
# Error:  4855    0.742698
# Name: ArrDelay, dtype: float64
# Error:  4856    10.685763
# Name: ArrDelay, dtype: float64
# Error:  4857    220.825868
# Name: ArrDelay, dtype: float64
# Error:  4858    2.734611
# Name: ArrDelay, dtype: float64
# Error:  4859    0.458381
# Name: ArrDelay, dtype: float64
# Error:  4860    1.468142
# Name: ArrDelay, dtype: float64
# Error:  4861    2.949317
# Name: ArrDelay, dtype: float64
# Error:  4862    139.490672
# Name: ArrDelay, dtype: float64
# Error:  4863    4.071056
# Name: ArrDelay, dtype: float64
# Error:  4864    41.211729
# Name: ArrDelay, dtype: float64
# Error:  4865    5.749517
# Name: ArrDelay, dtype: float64
# Error:  4866    13.541529
# Name: ArrDelay, dtype: float64
# Error:  4867    222.395904
# Name: ArrDelay, dtype: float64
# Error:  4868    0.035615
# Name: ArrDelay, dtype: float64
# Error:  4869    179.333987
# Name: ArrDelay, dtype: float64
# Error:  4870    14.780256
# Name: ArrDelay, dtype: float64
# Error:  4871    473.675443
# Name: ArrDelay, dtype: float64
# Error:  4872    1.167588
# Name: ArrDelay, dtype: float64
# Error:  4873    29.063634
# Name: ArrDelay, dtype: float64
# Error:  4874    0.265622
# Name: ArrDelay, dtype: float64
# Error:  4875    3.521303
# Name: ArrDelay, dtype: float64
# Error:  4876    20.386053
# Name: ArrDelay, dtype: float64
# Error:  4877    367.160175
# Name: ArrDelay, dtype: float64
# Error:  4878    720.832154
# Name: ArrDelay, dtype: float64
# Error:  4879    223.791274
# Name: ArrDelay, dtype: float64
# Error:  4880    0.678424
# Name: ArrDelay, dtype: float64
# Error:  4881    14.486811
# Name: ArrDelay, dtype: float64
# Error:  4882    4.287014
# Name: ArrDelay, dtype: float64
# Error:  4883    15.496297
# Name: ArrDelay, dtype: float64
# Error:  4884    7.056749
# Name: ArrDelay, dtype: float64
# Error:  4885    7.454154
# Name: ArrDelay, dtype: float64
# Error:  4886    107.220146
# Name: ArrDelay, dtype: float64
# Error:  4887    2.129002
# Name: ArrDelay, dtype: float64
# Error:  4888    24.44562
# Name: ArrDelay, dtype: float64
# Error:  4889    4.962431
# Name: ArrDelay, dtype: float64
# Error:  4890    72.749781
# Name: ArrDelay, dtype: float64
# Error:  4891    176.296844
# Name: ArrDelay, dtype: float64
# Error:  4892    2.347994
# Name: ArrDelay, dtype: float64
# Error:  4893    469.089767
# Name: ArrDelay, dtype: float64
# Error:  4894    8.311301
# Name: ArrDelay, dtype: float64
# Error:  4895    49.109193
# Name: ArrDelay, dtype: float64
# Error:  4896    71.378969
# Name: ArrDelay, dtype: float64
# Error:  4897    8.535384
# Name: ArrDelay, dtype: float64
# Error:  4898    30.069053
# Name: ArrDelay, dtype: float64
# Error:  4899    263.210008
# Name: ArrDelay, dtype: float64
# Error:  4900    4.059348
# Name: ArrDelay, dtype: float64
# Error:  4901    74.973555
# Name: ArrDelay, dtype: float64
# Error:  4902    0.028262
# Name: ArrDelay, dtype: float64
# Error:  4903    25.667813
# Name: ArrDelay, dtype: float64
# Error:  4904    3.110675
# Name: ArrDelay, dtype: float64
# Error:  4905    10.591073
# Name: ArrDelay, dtype: float64
# Error:  4906    63.38526
# Name: ArrDelay, dtype: float64
# Error:  4907    0.095187
# Name: ArrDelay, dtype: float64
# Error:  4908    79.430521
# Name: ArrDelay, dtype: float64
# Error:  4909    207.78979
# Name: ArrDelay, dtype: float64
# Error:  4910    3.220824
# Name: ArrDelay, dtype: float64
# Error:  4911    325.478204
# Name: ArrDelay, dtype: float64
# Error:  4912    0.962531
# Name: ArrDelay, dtype: float64
# Error:  4913    0.491302
# Name: ArrDelay, dtype: float64
# Error:  4914    16.694822
# Name: ArrDelay, dtype: float64
# Error:  4915    0.325699
# Name: ArrDelay, dtype: float64
# Error:  4916    104.598472
# Name: ArrDelay, dtype: float64
# Error:  4917    3082.578366
# Name: ArrDelay, dtype: float64
# Error:  4918    284.825823
# Name: ArrDelay, dtype: float64
# Error:  4919    145.873192
# Name: ArrDelay, dtype: float64
# Error:  4920    95.088626
# Name: ArrDelay, dtype: float64
# Error:  4921    17.570097
# Name: ArrDelay, dtype: float64
# Error:  4922    34.94196
# Name: ArrDelay, dtype: float64
# Error:  4923    21.640964
# Name: ArrDelay, dtype: float64
# Error:  4924    20.350223
# Name: ArrDelay, dtype: float64
# Error:  4925    3.842938
# Name: ArrDelay, dtype: float64
# Error:  4926    181.360291
# Name: ArrDelay, dtype: float64
# Error:  4927    138.838977
# Name: ArrDelay, dtype: float64
# Error:  4928    4.864629
# Name: ArrDelay, dtype: float64
# Error:  4929    118.000175
# Name: ArrDelay, dtype: float64
# Error:  4930    11.398256
# Name: ArrDelay, dtype: float64
# Error:  4931    612.439741
# Name: ArrDelay, dtype: float64
# Error:  4932    383.332994
# Name: ArrDelay, dtype: float64
# Error:  4933    9.81031
# Name: ArrDelay, dtype: float64
# Error:  4934    0.020136
# Name: ArrDelay, dtype: float64
# Error:  4935    0.994123
# Name: ArrDelay, dtype: float64
# Error:  4936    77.891145
# Name: ArrDelay, dtype: float64
# Error:  4937    317.880373
# Name: ArrDelay, dtype: float64
# Error:  4938    274.352308
# Name: ArrDelay, dtype: float64
# Error:  4939    112.074781
# Name: ArrDelay, dtype: float64
# Error:  4940    2.014786
# Name: ArrDelay, dtype: float64
# Error:  4941    7.02411
# Name: ArrDelay, dtype: float64
# Error:  4942    505.839233
# Name: ArrDelay, dtype: float64
# Error:  4943    147.741536
# Name: ArrDelay, dtype: float64
# Error:  4944    0.000931
# Name: ArrDelay, dtype: float64
# Error:  4945    24.169335
# Name: ArrDelay, dtype: float64
# Error:  4946    40.722686
# Name: ArrDelay, dtype: float64
# Error:  4947    184.344596
# Name: ArrDelay, dtype: float64
# Error:  4948    0.001343
# Name: ArrDelay, dtype: float64
# Error:  4949    311.067489
# Name: ArrDelay, dtype: float64
# Error:  4950    64.845305
# Name: ArrDelay, dtype: float64
# Error:  4951    6.373271
# Name: ArrDelay, dtype: float64
# Error:  4952    721.971347
# Name: ArrDelay, dtype: float64
# Error:  4953    154.00654
# Name: ArrDelay, dtype: float64
# Error:  4954    624.726918
# Name: ArrDelay, dtype: float64
# Error:  4955    7.392327
# Name: ArrDelay, dtype: float64
# Error:  4956    107.259318
# Name: ArrDelay, dtype: float64
# Error:  4957    83.940332
# Name: ArrDelay, dtype: float64
# Error:  4958    98.509362
# Name: ArrDelay, dtype: float64
# Error:  4959    5.479435
# Name: ArrDelay, dtype: float64
# Error:  4960    57.736963
# Name: ArrDelay, dtype: float64
# Error:  4961    191.397396
# Name: ArrDelay, dtype: float64
# Error:  4962    1.724585
# Name: ArrDelay, dtype: float64
# Error:  4963    262.429539
# Name: ArrDelay, dtype: float64
# Error:  4964    14.539697
# Name: ArrDelay, dtype: float64
# Error:  4965    263.865527
# Name: ArrDelay, dtype: float64
# Error:  4966    39.661142
# Name: ArrDelay, dtype: float64
# Error:  4967    15.144896
# Name: ArrDelay, dtype: float64
# Error:  4968    30.145312
# Name: ArrDelay, dtype: float64
# Error:  4969    61.666043
# Name: ArrDelay, dtype: float64
# Error:  4970    32.456985
# Name: ArrDelay, dtype: float64
# Error:  4971    0.123665
# Name: ArrDelay, dtype: float64
# Error:  4972    221.071147
# Name: ArrDelay, dtype: float64
# Error:  4973    53.089986
# Name: ArrDelay, dtype: float64
# Error:  4974    1.07433
# Name: ArrDelay, dtype: float64
# Error:  4975    1.266249
# Name: ArrDelay, dtype: float64
# Error:  4976    1.098344
# Name: ArrDelay, dtype: float64
# Error:  4977    67.635219
# Name: ArrDelay, dtype: float64
# Error:  4978    154.963073
# Name: ArrDelay, dtype: float64
# Error:  4979    3.781513
# Name: ArrDelay, dtype: float64
# Error:  4980    1.163018
# Name: ArrDelay, dtype: float64
# Error:  4981    5.197674
# Name: ArrDelay, dtype: float64
# Error:  4982    1.209468
# Name: ArrDelay, dtype: float64
# Error:  4983    79.941295
# Name: ArrDelay, dtype: float64
# Error:  4984    440.779412
# Name: ArrDelay, dtype: float64
# Error:  4985    12.993072
# Name: ArrDelay, dtype: float64
# Error:  4986    1105.499216
# Name: ArrDelay, dtype: float64
# Error:  4987    9.188802
# Name: ArrDelay, dtype: float64
# Error:  4988    2.917248
# Name: ArrDelay, dtype: float64
# Error:  4989    4.560128
# Name: ArrDelay, dtype: float64
# Error:  4990    0.869645
# Name: ArrDelay, dtype: float64
# Error:  4991    21.149594
# Name: ArrDelay, dtype: float64
# Error:  4992    5.842857
# Name: ArrDelay, dtype: float64
# Error:  4993    8.432853
# Name: ArrDelay, dtype: float64
# Error:  4994    13.157192
# Name: ArrDelay, dtype: float64
# Error:  4995    89.219917
# Name: ArrDelay, dtype: float64
# Error:  4996    60.236321
# Name: ArrDelay, dtype: float64
# Error:  4997    1336.408374
# Name: ArrDelay, dtype: float64
# Error:  4998    89.516294
# Name: ArrDelay, dtype: float64
# Error:  4999    130.102376
# Name: ArrDelay, dtype: float64
